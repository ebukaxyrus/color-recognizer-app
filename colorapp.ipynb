# %%
pip install streamlit opencv-python pandas
# Out:
# Requirement already satisfied: streamlit in c:\users\smart axis\anaconda3\lib\site-packages (1.32.0)
# Requirement already satisfied: opencv-python in c:\users\smart axis\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: pandas in c:\users\smart axis\appdata\roaming\python\python312\site-packages (2.2.3)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\smart axis\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\smart axis\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\smart axis\anaconda3\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\smart axis\anaconda3\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\smart axis\anaconda3\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\smart axis\anaconda3\lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\smart axis\anaconda3\lib\site-packages (from streamlit) (10.3.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\smart axis\anaconda3\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\smart axis\anaconda3\lib\site-packages (from streamlit) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\smart axis\anaconda3\lib\site-packages (from streamlit) (2.32.2)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\smart axis\anaconda3\lib\site-packages (from streamlit) (13.3.5)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\smart axis\anaconda3\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\smart axis\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\smart axis\anaconda3\lib\site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\smart axis\anaconda3\lib\site-packages (from streamlit) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\smart axis\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\smart axis\anaconda3\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\smart axis\anaconda3\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\smart axis\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\smart axis\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\smart axis\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: jinja2 in c:\users\smart axis\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\smart axis\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in c:\users\smart axis\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\smart axis\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\smart axis\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: six>=1.5 in c:\users\smart axis\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\smart axis\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\smart axis\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\smart axis\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\smart axis\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\smart axis\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\smart axis\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\smart axis\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\smart axis\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\smart axis\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\smart axis\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\smart axis\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\smart axis\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\smart axis\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import pandas as pd
import cv2
from PIL import Image
import numpy as np

st.set_page_config(page_title="AI Color Recognizer", layout="centered")

st.title("🎨 AI Color Recognizer for Kids")
st.write("Upload an image and click to see the closest color name!")

# Upload image
uploaded_file = st.file_uploader("wallhaven-jx632y.jpg", type=["jpg", "jpeg", "png"])

# Color dataset
colors = pd.DataFrame({
    'color_name': ['Red', 'Green', 'Blue', 'Yellow', 'Black', 'White', 'Gray', 'Orange', 'Purple'],
    'R': [255, 0, 0, 255, 0, 255, 128, 255, 128],
    'G': [0, 255, 0, 255, 0, 255, 128, 165, 0],
    'B': [0, 0, 255, 0, 0, 255, 128, 0, 128]
})

# Match color function
def get_color_name(R, G, B):
    min_diff = float('inf')
    cname = ""
    for i in range(len(colors)):
        d = abs(R - colors.loc[i, "R"]) + abs(G - colors.loc[i, "G"]) + abs(B - colors.loc[i, "B"])
        if d < min_diff:
            min_diff = d
            cname = colors.loc[i, "color_name"]
    return cname

if uploaded_file:
    # Load image
    img = Image.open(uploaded_file)
    img_array = np.array(img)

    st.image(img_array, caption="Click below to select a pixel.", use_column_width=True)

    st.markdown("### 🔍 Pick a pixel coordinate")

    col1, col2 = st.columns(2)
    with col1:
        x = st.number_input("X (horizontal)", min_value=0, max_value=img_array.shape[1]-1, value=50)
    with col2:
        y = st.number_input("Y (vertical)", min_value=0, max_value=img_array.shape[0]-1, value=50)

    if st.button("Detect Color"):
        r, g, b = img_array[int(y), int(x)][:3]
        color_name = get_color_name(r, g, b)

        st.markdown(f"### 🎯 Result at ({x}, {y})")
        st.markdown(f"**Color name:** {color_name}")
        st.markdown(f"**RGB:** ({r}, {g}, {b})")

        st.markdown(
            f"<div style='width:100px;height:50px;background-color:rgb({r},{g},{b});border:1px solid black;'></div>",
            unsafe_allow_html=True
        )
